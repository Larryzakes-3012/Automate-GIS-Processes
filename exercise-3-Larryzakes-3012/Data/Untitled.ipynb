# %%
world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))

# %%
world.plot()
# Out:
# <AxesSubplot: >

# %%
world
# Out:
#          pop_est      continent                      name iso_a3  gdp_md_est  \
# 0       889953.0        Oceania                      Fiji    FJI        5496
# 1     58005463.0         Africa                  Tanzania    TZA       63177
# 2       603253.0         Africa                 W. Sahara    ESH         907
# 3     37589262.0  North America                    Canada    CAN     1736425
# 4    328239523.0  North America  United States of America    USA    21433226
# ..           ...            ...                       ...    ...         ...
# 172    6944975.0         Europe                    Serbia    SRB       51475
# 173     622137.0         Europe                Montenegro    MNE        5542
# 174    1794248.0         Europe                    Kosovo    -99        7926
# 175    1394973.0  North America       Trinidad and Tobago    TTO       24269
# 176   11062113.0         Africa                  S. Sudan    SSD       11998
#
#                                               geometry
# 0    MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1    POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2    POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3    MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4    MULTIPOLYGON (((-122.84000 49.00000, -120.0000...
# ..                                                 ...
# 172  POLYGON ((18.82982 45.90887, 18.82984 45.90888...
# 173  POLYGON ((20.07070 42.58863, 19.80161 42.50009...
# 174  POLYGON ((20.59025 41.85541, 20.52295 42.21787...
# 175  POLYGON ((-61.68000 10.76000, -61.10500 10.890...
# 176  POLYGON ((30.83385 3.50917, 29.95350 4.17370, ...
#
# [177 rows x 6 columns]

# %%
world = world[['continent', 'geometry']]

# %%
world
# Out:
#          continent                                           geometry
# 0          Oceania  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1           Africa  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2           Africa  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3    North America  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4    North America  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...
# ..             ...                                                ...
# 172         Europe  POLYGON ((18.82982 45.90887, 18.82984 45.90888...
# 173         Europe  POLYGON ((20.07070 42.58863, 19.80161 42.50009...
# 174         Europe  POLYGON ((20.59025 41.85541, 20.52295 42.21787...
# 175  North America  POLYGON ((-61.68000 10.76000, -61.10500 10.890...
# 176         Africa  POLYGON ((30.83385 3.50917, 29.95350 4.17370, ...
#
# [177 rows x 2 columns]

# %%
continents = world.dissolve(by='continent')

# %%
world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))

# %%
world = world[['continent', 'geometry', 'pop_est']]

# %%
world
# Out:
#          continent                                           geometry  \
# 0          Oceania  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1           Africa  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2           Africa  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3    North America  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4    North America  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...
# ..             ...                                                ...
# 172         Europe  POLYGON ((18.82982 45.90887, 18.82984 45.90888...
# 173         Europe  POLYGON ((20.07070 42.58863, 19.80161 42.50009...
# 174         Europe  POLYGON ((20.59025 41.85541, 20.52295 42.21787...
# 175  North America  POLYGON ((-61.68000 10.76000, -61.10500 10.890...
# 176         Africa  POLYGON ((30.83385 3.50917, 29.95350 4.17370, ...
#
#          pop_est
# 0       889953.0
# 1     58005463.0
# 2       603253.0
# 3     37589262.0
# 4    328239523.0
# ..           ...
# 172    6944975.0
# 173     622137.0
# 174    1794248.0
# 175    1394973.0
# 176   11062113.0
#
# [177 rows x 3 columns]

# %%
continents = world.dissolve(by='continent', aggfunc='sum')

# %%
continents
# Out:
#                                                                   geometry  \
# continent
# Africa                   MULTIPOLYGON (((-11.43878 6.78592, -11.70819 6...
# Antarctica               MULTIPOLYGON (((-61.13898 -79.98137, -60.61012...
# Asia                     MULTIPOLYGON (((48.67923 14.00320, 48.23895 13...
# Europe                   MULTIPOLYGON (((-53.55484 2.33490, -53.77852 2...
# North America            MULTIPOLYGON (((-155.22217 19.23972, -155.5421...
# Oceania                  MULTIPOLYGON (((147.91405 -43.21152, 147.56456...
# Seven seas (open ocean)  POLYGON ((68.93500 -48.62500, 69.58000 -48.940...
# South America            MULTIPOLYGON (((-68.63999 -55.58002, -69.23210...
#
#                               pop_est
# continent
# Africa                   1.306370e+09
# Antarctica               4.490000e+03
# Asia                     4.550277e+09
# Europe                   7.454125e+08
# North America            5.837560e+08
# Oceania                  4.120487e+07
# Seven seas (open ocean)  1.400000e+02
# South America            4.270667e+08

# %%
continents.plot(column = 'pop_est', scheme='quantiles', cmap='YlOrRd', legend = True)
# Out:
# <AxesSubplot: >

# %%
# classification

# %%
pip install libpysal
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting libpysal
#   Downloading libpysal-4.7.0-py3-none-any.whl (2.4 MB)
#      ---------------------------------------- 2.4/2.4 MB 557.5 kB/s eta 0:00:00
# Requirement already satisfied: requests in c:\users\olanrewaju oludare\appdata\roaming\python\python310\site-packages (from libpysal) (2.28.1)
# Requirement already satisfied: pandas in c:\users\olanrewaju oludare\appdata\roaming\python\python310\site-packages (from libpysal) (1.5.2)
# Requirement already satisfied: packaging in c:\users\olanrewaju oludare\appdata\roaming\python\python310\site-packages (from libpysal) (21.3)
# Requirement already satisfied: scipy>=0.11 in c:\users\olanrewaju oludare\appdata\roaming\python\python310\site-packages (from libpysal) (1.10.0)
# Requirement already satisfied: jinja2 in c:\users\olanrewaju oludare\appdata\roaming\python\python310\site-packages (from libpysal) (3.1.2)
# Collecting platformdirs
#   Downloading platformdirs-2.6.2-py3-none-any.whl (14 kB)
# Requirement already satisfied: numpy>=1.3 in c:\users\olanrewaju oludare\appdata\roaming\python\python310\site-packages (from libpysal) (1.23.4)
# Requirement already satisfied: beautifulsoup4 in c:\users\olanrewaju oludare\appdata\roaming\python\python310\site-packages (from libpysal) (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\olanrewaju oludare\appdata\roaming\python\python310\site-packages (from beautifulsoup4->libpysal) (2.3.2.post1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\olanrewaju oludare\appdata\roaming\python\python310\site-packages (from jinja2->libpysal) (2.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\olanrewaju oludare\appdata\roaming\python\python310\site-packages (from packaging->libpysal) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\olanrewaju oludare\appdata\roaming\python\python310\site-packages (from pandas->libpysal) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\olanrewaju oludare\appdata\roaming\python\python310\site-packages (from pandas->libpysal) (2022.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\olanrewaju oludare\appdata\roaming\python\python310\site-packages (from requests->libpysal) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\olanrewaju oludare\appdata\roaming\python\python310\site-packages (from requests->libpysal) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\olanrewaju oludare\appdata\roaming\python\python310\site-packages (from requests->libpysal) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\olanrewaju oludare\appdata\roaming\python\python310\site-packages (from requests->libpysal) (3.4)
# Requirement already satisfied: six>=1.5 in c:\users\olanrewaju oludare\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.1->pandas->libpysal) (1.16.0)
# Installing collected packages: platformdirs, libpysal
# Successfully installed libpysal-4.7.0 platformdirs-2.6.2
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x00000218A4C0E7D0>: Failed to establish a new connection: [Errno 11002] getaddrinfo failed')': /packages/11/09/aa8f068105c4ba5c0cb8093b021ace51ea1fc72308eed52427403cc8fa8e/libpysal-4.7.0-py3-none-any.whl
#   WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x00000218A4C0EAA0>: Failed to establish a new connection: [Errno 11002] getaddrinfo failed')': /packages/11/09/aa8f068105c4ba5c0cb8093b021ace51ea1fc72308eed52427403cc8fa8e/libpysal-4.7.0-py3-none-any.whl
#   WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x00000218A4C0EC50>: Failed to establish a new connection: [Errno 11002] getaddrinfo failed')': /packages/11/09/aa8f068105c4ba5c0cb8093b021ace51ea1fc72308eed52427403cc8fa8e/libpysal-4.7.0-py3-none-any.whl
#   WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x00000218A4C0EE00>: Failed to establish a new connection: [Errno 11002] getaddrinfo failed')': /packages/11/09/aa8f068105c4ba5c0cb8093b021ace51ea1fc72308eed52427403cc8fa8e/libpysal-4.7.0-py3-none-any.whl
#   WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x00000218A4C0EFB0>: Failed to establish a new connection: [Errno 11002] getaddrinfo failed')': /packages/11/09/aa8f068105c4ba5c0cb8093b021ace51ea1fc72308eed52427403cc8fa8e/libpysal-4.7.0-py3-none-any.whl
#
# [notice] A new release of pip available: 22.3 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import libpysal as ps
# Out:
# C:\Users\Olanrewaju Oludare\AppData\Roaming\Python\Python310\site-packages\geopandas\_compat.py:123: UserWarning: The Shapely GEOS version (3.10.3-CAPI-1.16.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
pth = ps.examples.get_path("columbus.shp")

# %%
tracts = gpd.GeoDataFrame.from_file(pth)

# %%
tracts.head(3)
# Out:
#        AREA  PERIMETER  COLUMBUS_  COLUMBUS_I  POLYID  NEIG      HOVAL  \
# 0  0.309441   2.440629          2           5       1     5  80.467003
# 1  0.259329   2.236939          3           1       2     1  44.567001
# 2  0.192468   2.187547          4           6       3     6  26.350000
#
#       INC      CRIME      OPEN  ...  DISCBD          X          Y  NSA  NSB  \
# 0  19.531  15.725980  2.850747  ...    5.03  38.799999  44.070000  1.0  1.0
# 1  21.232  18.801754  5.296720  ...    4.27  35.619999  42.380001  1.0  1.0
# 2  15.956  30.626781  4.534649  ...    3.89  39.820000  41.180000  1.0  1.0
#
#     EW   CP   THOUS  NEIGNO                                           geometry
# 0  1.0  0.0  1000.0  1005.0  POLYGON ((8.62413 14.23698, 8.55970 14.74245, ...
# 1  0.0  0.0  1000.0  1001.0  POLYGON ((8.25279 14.23694, 8.28276 14.22994, ...
# 2  1.0  0.0  1000.0  1006.0  POLYGON ((8.65331 14.00809, 8.81814 14.00205, ...
#
# [3 rows x 21 columns]

# %%
tracts['CRIME'].hist(bins=20)
plt.xlabel('CRIME\nResidential burglaries and vehicle thefts per 1000 households')
plt.ylabel('Number of neighbourhoods')
plt.title('Distribution of neighbourhoods by crime rate in Columbus, OH')
plt.show()

# %%
# the plot without classification scheme

# %%
tracts.plot(column='CRIME', cmap='OrRd', edgecolor='k', legend=True)
# Out:
# <AxesSubplot: >

# %%
# quantile classification

# %%
tracts.plot(column='CRIME', scheme='quantiles', k=3, cmap='OrRd', edgecolor='k', legend=True)
# Out:
# <AxesSubplot: >
